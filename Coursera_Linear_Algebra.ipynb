# %% [markdown]
# This is a notebook to document learning on Linear Algebra.

# %% [markdown]
# The below are test cells to see if I can import images from external cloud sources like Figma, where I might be inclined to do some diagramming.

# %% [markdown]
# from IPython import display
# display.Image("https://raw.githubusercontent.com/mljar/visual-identity/main/mercury/mercury_convert_notebook.png")

# %% [markdown]
# ![alternatvie text](https://raw.githubusercontent.com/mljar/visual-identity/main/mercury/mercury_convert_notebook.png)

# %% [markdown]
# <img src="https://raw.githubusercontent.com/mljar/visual-identity/main/mercury/mercury_convert_notebook.png") alt="Alternative text" />

# %% [markdown]
# ![convert notebook to web app](https://raw.githubusercontent.com/mljar/visual-identity/main/mercury/mercury_convert_notebook.png)

# %%
#![convert notebook to web app](https://raw.githubusercontent.com/mljar/visual-identity/main/mercury/mercury_convert_notebook.png)

# %%
#![alternatvie text](https://raw.githubusercontent.com/mljar/visual-identity/main/mercury/mercury_convert_notebook.png)

# %% [markdown]
# ![alternatvie text](https://raw.githubusercontent.com/mljar/visual-identity/main/mercury/mercury_convert_notebook.png)

# %% [markdown]
# ![Figma does not share individual images](https://www.figma.com/file/4qc6TfOuoFPgTKT8Ebq8zV/Corsera-Notes?node-id=0%3A1&t=qIeZd31F1UtXZGfK-1)

# %% [markdown]
# https://www.figma.com/file/4qc6TfOuoFPgTKT8Ebq8zV/Corsera-Notes?node-id=0%3A1&t=qIeZd31F1UtXZGfK-1

# %% [markdown]
# ![Screen%20Shot%202023-02-19%20at%2010.03.19%20AM.png](attachment:Screen%20Shot%202023-02-19%20at%2010.03.19%20AM.png)

# %% [markdown]
# In particular, the first system of sentences contains two sentences and
# two pieces of information.
# This means the system contains as many pieces of information as sentences and
# that's called a complete system.

# %% [markdown]
# ![Screen%20Shot%202023-02-19%20at%2010.09.13%20AM.png](attachment:Screen%20Shot%202023-02-19%20at%2010.09.13%20AM.png)

# %% [markdown]
# 05:17:
# Here I take Non-Singular to mean simply that we have two lines. Is their intersection what makes them complete?

# %% [markdown]
# Yes: We have two unknowns, but also two equations. We have enough information to fully map the system, be it lines or dogs, cats, birds and their colors. We can understand the system at each and every point. All our known.

# %% [markdown]
# ![Screen%20Shot%202023-02-20%20at%206.09.22%20AM.png](attachment:Screen%20Shot%202023-02-20%20at%206.09.22%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202023-02-20%20at%206.09.03%20AM.png](attachment:Screen%20Shot%202023-02-20%20at%206.09.03%20AM.png)

# %% [markdown]
# Here we look at turning lines into matrices. Below we include the definition of 'linear dependence', one line can be 'obtained' from the first. And visaversa, so each can be obtained from one another. We are just multiplying by scalars.
# ![Screen%20Shot%202023-02-20%20at%206.15.21%20AM.png](attachment:Screen%20Shot%202023-02-20%20at%206.15.21%20AM.png)

# %% [markdown]
# The determinant returns a 0 if the matrix is singular and a number different from 0 if the matrix is non singular.

# %% [markdown]
# ![Screen%20Shot%202023-02-20%20at%206.24.36%20AM.png](attachment:Screen%20Shot%202023-02-20%20at%206.24.36%20AM.png)

# %% [markdown]
# ![Screen%20Shot%202023-02-20%20at%206.25.31%20AM.png](attachment:Screen%20Shot%202023-02-20%20at%206.25.31%20AM.png)

# %% [markdown]
# Singular - as in the Singularity, or as in, the individual is a concept we generally regard as 'good' in society. But here, 'Singular' means incomplete. Whereas I tend to think of 'Singular' meaning all-in-one. All encompassing.
# ![Screen%20Shot%202023-02-20%20at%206.28.58%20AM.png](attachment:Screen%20Shot%202023-02-20%20at%206.28.58%20AM.png)

# %% [markdown]
# So far I'm enjoying these explanations a bit more then the Udacity 'Intro to Self Driving Car' explanations.

# %% [markdown]
# It would be super fun to add animation to this sequence in order to help ground me in the scene - basically as a sim applied to reality which would help me take the math seriously, but also start to understand that math can be applied to daily life, daily situations in life.
# ![Screen%20Shot%202023-02-20%20at%206.35.16%20AM.png](attachment:Screen%20Shot%202023-02-20%20at%206.35.16%20AM.png)

# %% [markdown]
# In fact, in the above scene, we only see one rover, there should be two. To help us visualize the problem. To be able to abstract a formula, from context, seems super useful.

# %% [markdown]
# ***You split the rocks between the two rovers. You first place 2 basalt samples (volcanic rock) and 3 meteorite rocks to Perseverance that weigh 15 grams in total.
# You then put 2 basalt samples and 4 meteorites to Curiosity that weigh 16 grams in total. ***

# %% [markdown]
# 2b + 3m = 15   |   2b + 4m = 16

# %% [markdown]
# b = (15 - 3m)/2

# %% [markdown]
# so, plugging b into the second equation, we get:

# %% [markdown]
# 15-3m + 4m = 16

# %% [markdown]
# 1m = 1

# %% [markdown]
# Plugging m of 1 back into the first equation:
# 2b + 3(1) = 15

# %% [markdown]
# b = 6

# %% [markdown]
# And on the quiz, I got the b and the m, reversed because I solved for b at the end then I used the placements of basalt, meteor in the answer, rather then mapping back to the symbolic representation of b = basalt = 6, vs. m = meteor = 1. I need to take the extra time to be careful returning back the real world domain. This demonstrates the mind's preference for visual cues and short cuts, where possible.![Screen%20Shot%202023-02-20%20at%207.00.59%20AM-2.png](attachment:Screen%20Shot%202023-02-20%20at%207.00.59%20AM-2.png)

# %% [markdown]
# Exit: 7:20 | 02-20-23

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Enter: 6:20 | 02-21-23

# %% [markdown]
# ![Screen%20Shot%202023-02-21%20at%206.24.45%20AM.png](attachment:Screen%20Shot%202023-02-21%20at%206.24.45%20AM.png)

# %% [markdown]
# "The problem is a familar one." Yes, this happened to me just yesterday.

# %% [markdown]
# ![Screen%20Shot%202023-02-21%20at%206.27.40%20AM.png](attachment:Screen%20Shot%202023-02-21%20at%206.27.40%20AM.png)

# %% [markdown]
# | Linear | Equations |
# | ----------- | ----------- |
# |1a + 1b + 1c = 10| |
# |1a + 2b + 2c = 15| |
# |1a + 1b + 2c = 12| |

# %% [markdown]
# Code from:
# https://www.geeksforgeeks.org/determinant-of-a-matrix/

# %%
# importing Numpy package
import numpy as np
  
# creating a 2X2 Numpy matrix
n_array = np.array([[50, 29], [30, 44]])
  
# Displaying the Matrix
print("Numpy Matrix is:")
print(n_array)
  
# calculating the determinant of matrix
det = np.linalg.det(n_array)
  
print("\nDeterminant of given 2X2 matrix:")
print(int(det))
# Out:
# Numpy Matrix is:
# [[50 29]
#  [30 44]]
#
# Determinant of given 2X2 matrix:
# 1330

# %%
# importing Numpy package
import numpy as np
  
# creating a 3X3 Numpy matrix
n_array = np.array([[50, 29, 20], [30, 44, 20]])
  
# Displaying the Matrix
print("Numpy Matrix is:")
print(n_array)
  
# calculating the determinant of matrix
#det = np.linalg.det(n_array)
  
print("\nDeterminant of given 3x3 Matrix cannot be determined using np.linalg.det(n_array).")
#print(int(det))
# Out:
# Numpy Matrix is:
# [[50 29 20]
#  [30 44 20]]
#
# Determinant of given 3x3 Matrix cannot be determined using np.linalg.det(n_array).

# %%
def determinantOfMatrix(mat, n):
 
    temp = [0]*n  # temporary array for storing row
    total = 1
    det = 1  # initialize result
 
    # loop for traversing the diagonal elements
    for i in range(0, n):
        index = i  # initialize the index
 
        # finding the index which has non zero value
        while(index < n and mat[index][i] == 0):
            index += 1
 
        if(index == n):  # if there is non zero element
            # the determinant of matrix as zero
            continue
 
        if(index != i):
            # loop for swapping the diagonal element row and index row
            for j in range(0, n):
                mat[index][j], mat[i][j] = mat[i][j], mat[index][j]
 
            # determinant sign changes when we shift rows
            # go through determinant properties
            det = det*int(pow(-1, index-i))
 
        # storing the values of diagonal row elements
        for j in range(0, n):
            temp[j] = mat[i][j]
 
        # traversing every row below the diagonal element
        for j in range(i+1, n):
            num1 = temp[i]     # value of diagonal element
            num2 = mat[j][i]   # value of next row element
 
            # traversing every column of row
            # and multiplying to every row
            for k in range(0, n):
                # multiplying to make the diagonal
                # element and next row element equal
 
                mat[j][k] = (num1*mat[j][k]) - (num2*temp[k])
 
            total = total * num1  # Det(kA)=kDet(A);
 
    # multiplying the diagonal elements to get determinant
    for i in range(0, n):
        det = det*mat[i][i]
 
    return int(det/total)  # Det(kA)/k=Det(A);

# %%
import numpy as np
    
    # mat=[[6 1 1]
    #      [4 -2 5]
    #      [2 8 7]]
 
mat = [[1, 0, 2, -1], 
       [3, 0, 0,  5], 
       [2, 1, 4, -3], 
       [1, 0, 5,  0] ]
N = len(mat)
     
# Function call
print("Determinant of the matrix is : ", determinantOfMatrix(mat, N))
# Out:
# Determinant of the matrix is :  30

# %%
import numpy as np
mat = [
       [1, 0, 2, -1],
       [3, 0, 0,  5], 
       [2, 1, 4, -3],  
       [1, 0, 5,  0]
      ]
print("Determinant of the matrix is : ", determinantOfMatrix(mat, N))
# Out:
# Determinant of the matrix is :  30

# %% [markdown]
# | Linear | Equations |
# | ----------- | ----------- |
# |1a + 1b + 1c = 10| |
# |1a + 2b + 2c = 15| |
# |1a + 1b + 2c = 12| |

# %%
import numpy as np
mat = [
       [1, 0, 2,  -1],
       [1, 1, 1,  10], 
       [1, 2, 2,  15],  
       [1, 1, 2,  12]
      ]
print("Determinant of the matrix is : ", determinantOfMatrix(mat, N))
# Out:
# Determinant of the matrix is :  10

# %% [markdown]
# ![Screen%20Shot%202023-02-21%20at%207.13.25%20AM.png](attachment:Screen%20Shot%202023-02-21%20at%207.13.25%20AM.png)
